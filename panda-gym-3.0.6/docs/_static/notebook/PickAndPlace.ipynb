# %% [markdown]
# <a href="https://colab.research.google.com/github/qgallouedec/panda-gym/blob/colab/PickAndPlace.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # `panda-gym` code example
#
# ## Install `panda-gym`

# %%
# %pip install panda-gym
# Out:
# Collecting panda-gym
#   Using cached panda_gym-3.0.7-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: gymnasium>=0.26 in e:\languages\anaconda3\envs\gym310\lib\site-packages (from panda-gym) (0.29.1)
# Collecting pybullet (from panda-gym)
#   Using cached pybullet-3.2.6.tar.gz (80.5 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy in e:\languages\anaconda3\envs\gym310\lib\site-packages (from panda-gym) (1.26.4)
# Requirement already satisfied: scipy in e:\languages\anaconda3\envs\gym310\lib\site-packages (from panda-gym) (1.13.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in e:\languages\anaconda3\envs\gym310\lib\site-packages (from gymnasium>=0.26->panda-gym) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in e:\languages\anaconda3\envs\gym310\lib\site-packages (from gymnasium>=0.26->panda-gym) (4.11.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in e:\languages\anaconda3\envs\gym310\lib\site-packages (from gymnasium>=0.26->panda-gym) (0.0.4)
# Using cached panda_gym-3.0.7-py3-none-any.whl (23 kB)
# Building wheels for collected packages: pybullet
#   Building wheel for pybullet (setup.py): started
#   Building wheel for pybullet (setup.py): still running...
#   Building wheel for pybullet (setup.py): still running...
#   Building wheel for pybullet (setup.py): still running...
#   Building wheel for pybullet (setup.py): still running...
#   Building wheel for pybullet (setup.py): finished with status 'done'
#   Created wheel for pybullet: filename=pybullet-3.2.6-cp310-cp310-win_amd64.whl size=67448011 sha256=008b8b8e6e6e3de87e847237a2817ff35425f902811efd5f03bcd1dd2eb5ef68
#   Stored in directory: c:\users\loewllzoe\appdata\local\pip\cache\wheels\52\17\85\7ebb8c1f1c59ed08fc2d259f51201cfa5849368ed5e421f83d
# Successfully built pybullet
# Installing collected packages: pybullet, panda-gym
# Successfully installed panda-gym-3.0.7 pybullet-3.2.6
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Interract

# %%
import gymnasium as gym
import panda_gym

env = gym.make("PandaPickAndPlace-v3", render_mode="rgb_array")
observation, info = env.reset()

images = [env.render()]
for _ in range(20):
    action = env.action_space.sample()
    observation, reward, terminated, truncated, info = env.step(action)
    images.append(env.render())

    if terminated or truncated:
        observation, info = env.reset()
        images.append(env.render())

env.close()

# %% [markdown]
# ## Convert into animation

# %%
#pip install numpngw
from numpngw import write_apng

write_apng("anim.png", images, delay=40)  # real-time rendering = 40 ms between frames

# %% [markdown]
# ## Show animation

# %%
from IPython.display import Image

Image(filename="anim.png")
